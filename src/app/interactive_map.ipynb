# %%
import plotly.graph_objects as go
import chart_studio
import chart_studio.plotly as py
import json

with open('../data/ChargeApp.geojson', 'r') as f:
    geojson_data = json.load(f)

# Create the base map
fig = go.Figure()

# Extract feature IDs and initial attribute ("cars") to use in the plot
feature_ids = list(range(len(geojson_data['features'])))
initial_attribute = [feature['properties']['cars'] for feature in geojson_data['features']]

# Add choropleth layer for initial attribute ("cars")
fig.add_trace(
    go.Choroplethmapbox(
        geojson=geojson_data,
        locations=feature_ids,
        featureidkey="properties.KREISID",
        z=initial_attribute,
        colorscale="Viridis",
        showscale=False,
        name="layer",
    )
)

# Update map layout and initial viewpoint
fig.update_layout(
    mapbox_style="carto-positron",
    mapbox_zoom=6,
    mapbox_center={"lat": 48.8660059206183, "lon": 9.22517678783754},
)

# Define the dropdown menu
dropdown_buttons = [
    {
        "args": [
            {"z": [feature['properties'][attr] for feature in geojson_data['features']]},
            {"title": f"Map of {attr.replace('_', ' ').title()}"},
        ],
        "label": attr.replace('_', ' ').title(),
        "method": "restyle",
    }
    for attr in [
        'population',
        'stations_per_pop',
        'pop_per_station',
        'cars_per_pop',
        'ev_per_pop',
        'ev_per_car',
        'ev_per_station',
    ]
]

# Add dropdown menu to layout
fig.update_layout(
    updatemenus=[
        {
            "buttons": dropdown_buttons,
            "direction": "down",
            "showactive": True,
        }
    ]
)

chart_studio.tools.set_credentials_file(username='Purin', api_key='I3fXu4AWEhY4M6Dk0xys')
py.plot(fig, filename='EV_charging_map', auto_open=True)
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/chart_studio/plotly/plotly.py:1463, in _create_or_update(data, filetype)
#    1462 try:
# -> 1463     lookup_res = v2.files.lookup(filename)
#    1464     if isinstance(lookup_res.content, bytes):
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/chart_studio/api/v2/files.py:85, in lookup(path, parent, user, exists)
#      84 params = make_params(path=path, parent=parent, user=user, exists=exists)
# ---> 85 return request("get", url, params=params)
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/retrying.py:257, in Retrying.call(self, fn, *args, **kwargs)
#     256 if not self.should_reject(attempt):
# --> 257     return attempt.get(self._wrap_exception)
#     259 if self._after_attempts:
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/retrying.py:301, in Attempt.get(self, wrap_exception)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/six.py:719, in reraise(tp, value, tb)
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/chart_studio/api/v2/utils.py:180, in request(method, url, **kwargs)
#     179     raise exceptions.PlotlyRequestError(message, status_code, content)
# --> 180 validate_response(response)
#     181 return response
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/chart_studio/api/v2/utils.py:82, in validate_response(response)
#      80     message = content if content else "No Content"
# ---> 82 raise exceptions.PlotlyRequestError(message, status_code, content)
#
# PlotlyRequestError: Not found.
#
# During handling of the above exception, another exception occurred:
#
# PlotlyRequestError                        Traceback (most recent call last)
# /workspaces/python3-poetry-pyenv/src/app/map.ipynb Cell 1 line 6
#      <a href='vscode-notebook-cell://dev-container%2B7b22766f6c756d654e616d65223a22707974686f6e332d706f657472792d7079656e76222c22666f6c646572223a22707974686f6e332d706f657472792d7079656e76222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/workspaces/python3-poetry-pyenv/src/app/map.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=57'>58</a> fig.update_layout(
#      <a href='vscode-notebook-cell://dev-container%2B7b22766f6c756d654e616d65223a22707974686f6e332d706f657472792d7079656e76222c22666f6c646572223a22707974686f6e332d706f657472792d7079656e76222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/workspaces/python3-poetry-pyenv/src/app/map.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=58'>59</a>     updatemenus=[
#      <a href='vscode-notebook-cell://dev-container%2B7b22766f6c756d654e616d65223a22707974686f6e332d706f657472792d7079656e76222c22666f6c646572223a22707974686f6e332d706f657472792d7079656e76222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/workspaces/python3-poetry-pyenv/src/app/map.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=59'>60</a>         {
#    (...)
#      <a href='vscode-notebook-cell://dev-container%2B7b22766f6c756d654e616d65223a22707974686f6e332d706f657472792d7079656e76222c22666f6c646572223a22707974686f6e332d706f657472792d7079656e76222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/workspaces/python3-poetry-pyenv/src/app/map.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=64'>65</a>     ]
#      <a href='vscode-notebook-cell://dev-container%2B7b22766f6c756d654e616d65223a22707974686f6e332d706f657472792d7079656e76222c22666f6c646572223a22707974686f6e332d706f657472792d7079656e76222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/workspaces/python3-poetry-pyenv/src/app/map.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=65'>66</a> )
#      <a href='vscode-notebook-cell://dev-container%2B7b22766f6c756d654e616d65223a22707974686f6e332d706f657472792d7079656e76222c22666f6c646572223a22707974686f6e332d706f657472792d7079656e76222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/workspaces/python3-poetry-pyenv/src/app/map.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=67'>68</a> chart_studio.tools.set_credentials_file(username='Purin', api_key='I3fXu4AWEhY4M6Dk0xys')
# ---> <a href='vscode-notebook-cell://dev-container%2B7b22766f6c756d654e616d65223a22707974686f6e332d706f657472792d7079656e76222c22666f6c646572223a22707974686f6e332d706f657472792d7079656e76222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/workspaces/python3-poetry-pyenv/src/app/map.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=68'>69</a> py.plot(fig, filename='EV_charging_map', auto_open=True)
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/chart_studio/plotly/plotly.py:286, in plot(figure_or_data, validate, **plot_options)
#     283     _set_grid_column_references(figure, grid)
#     284     payload["figure"] = figure
# --> 286 file_info = _create_or_update(payload, "plot")
#     288 # Compute viewing URL
#     289 if sharing == "secret":
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/chart_studio/plotly/plotly.py:1488, in _create_or_update(data, filetype)
#    1475                 raise _plotly_utils.exceptions.PlotlyError(
#    1476                     """
#    1477 '{filename}' is already a {other_filetype} in your account.
#    (...)
#    1484                     )
#    1485                 )
#    1487         except exceptions.PlotlyRequestError:
# -> 1488             res = api_module.create(data)
#    1489     else:
#    1490         res = api_module.create(data)
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/chart_studio/api/v2/plots.py:18, in create(body)
#      10 """
#      11 Create a new plot.
#      12
#    (...)
#      15
#      16 """
#      17 url = build_url(RESOURCE)
# ---> 18 return request("post", url, json=body)
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/retrying.py:257, in Retrying.call(self, fn, *args, **kwargs)
#     254     attempt = Attempt(tb, attempt_number, True)
#     256 if not self.should_reject(attempt):
# --> 257     return attempt.get(self._wrap_exception)
#     259 if self._after_attempts:
#     260     self._after_attempts(attempt_number)
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/retrying.py:301, in Attempt.get(self, wrap_exception)
#     299         raise RetryError(self)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#     303     return self.value
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     248     self._before_attempts(attempt_number)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#     253     tb = sys.exc_info()
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/chart_studio/api/v2/utils.py:180, in request(method, url, **kwargs)
#     178     content = response.content if response else "No content"
#     179     raise exceptions.PlotlyRequestError(message, status_code, content)
# --> 180 validate_response(response)
#     181 return response
#
# File /workspaces/python3-poetry-pyenv/.venv/lib/python3.10/site-packages/chart_studio/api/v2/utils.py:82, in validate_response(response)
#      79 if not message:
#      80     message = content if content else "No Content"
# ---> 82 raise exceptions.PlotlyRequestError(message, status_code, content)
#
# PlotlyRequestError: This file is too big! Your current subscription is limited to 524.288 KB uploads. For more information, please visit: https://plotly.com/get-pricing/.
